# %% [markdown]
# <a href="https://colab.research.google.com/github/lakhshuyaa/data-visualization/blob/main/DV_exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv

# %%
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-108d4f24-4707-4b74-918d-529c4ef16ce5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-108d4f24-4707-4b74-918d-529c4ef16ce5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("Global YouTube Statistics.csv", encoding="latin1")

df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv("Global YouTube Statistics.csv", encoding="latin1")

# Display descriptive statistics
print(df.describe())
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
df.to_excel("Global YouTube Statistics.xlsx", index=False)
print("DataFrame successfully saved to 'Global YouTube Statistics.xlsx'")
# Out:
# DataFrame successfully saved to 'Global YouTube Statistics.xlsx'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort the DataFrame by 'subscribers' in descending order and select the top 10
top_10_youtubers = df.sort_values(by='subscribers', ascending=False).head(10)

# Create the bar plot
plt.figure(figsize=(12, 7))
sns.barplot(x='Youtuber', y='subscribers', data=top_10_youtubers, palette='viridis')

# Add title and labels
plt.title('Top 10 YouTubers by Subscriber Count', fontsize=16)
plt.xlabel('Youtuber', fontsize=12)
plt.ylabel('Subscribers', fontsize=12)
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()
# Out:
# /tmp/ipykernel_657/3281158649.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Youtuber', y='subscribers', data=top_10_youtubers, palette='viridis')

# %% [markdown]
# Please let me know which specific column you'd like to query, or if you had a different kind of SQL-like operation in mind (e.g., filtering, aggregation).

# %%
youtuber_column = df['Youtuber']
print(youtuber_column.head())
# Out:
# 0                      T-Series
# 1                YouTube Movies
# 2                       MrBeast
# 3    Cocomelon - Nursery Rhymes
# 4                     SET India
# Name: Youtuber, dtype: object

# %%
print(df.columns)
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.to_csv("Global YouTube Statistics.csv", index=False)
print("DataFrame successfully saved to 'Global YouTube Statistics.csv'")
# Out:
# DataFrame successfully saved to 'Global YouTube Statistics.csv'

# %%
df.to_excel("Global YouTube Statistics.xlsx", index=False)
print("DataFrame successfully saved to 'Global YouTube Statistics.xlsx'")
# Out:
# DataFrame successfully saved to 'Global YouTube Statistics.xlsx'

# %%
df.to_json("Global YouTube Statistics.json", orient="records", indent=4)
print("DataFrame successfully saved to 'Global YouTube Statistics.json'")
# Out:
# DataFrame successfully saved to 'Global YouTube Statistics.json'

# %%
import sqlite3

# Create a SQLite database in memory (or a file if you specify a path)
conn = sqlite3.connect(':memory:')

# Write the DataFrame to a SQLite table
df.to_sql('youtube_stats', conn, if_exists='replace', index=False)

print("DataFrame successfully converted to a SQLite table named 'youtube_stats'.")

# Example SQL query
query = "SELECT Youtuber, subscribers FROM youtube_stats ORDER BY subscribers DESC LIMIT 5"
sql_result_df = pd.read_sql_query(query, conn)
display(sql_result_df)

# Close the connection
conn.close()
# Out:
# DataFrame successfully converted to a SQLite table named 'youtube_stats'.
#                      Youtuber  subscribers
# 0                    T-Series    245000000
# 1              YouTube Movies    170000000
# 2                     MrBeast    166000000
# 3  Cocomelon - Nursery Rhymes    162000000
# 4                   SET India    159000000
